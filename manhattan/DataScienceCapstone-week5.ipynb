# %% [markdown]
# # Coursera Battle of the neighbourhoods
# ## Opening a new Jazz Club in Manhattan
#
#
#
#
# Author: Mark Chinnock
# Date: June 2020
#
#
#
# ### Content
#
# 1.	[Introduction](#introduction)
#
#     1.1 [Discussion of the "background situation"](#background)
#
#     1.2 [Problem](#problem)
#
#     1.3 [Audience](#audience)
#
#
# 2.	[Data](#data)
# 3. [Methodology](#methodology)
# 4. [Results](#results)
# 5. [Discussion](#discussion)
# 6. [Conclusion](#conclusion)

# %% [markdown]
# # 1. Introduction <a name="introduction"></a>
# I am a successful Jazz musician wanting to move to New York City and open a new venue of my own in Manhattan.  I want to locate my venue away from other clubs but in a similar neighborhood.  I have a limited knowledge of the neighborhoods.

# %% [markdown]
# ## 1.1 Background <a name="background"></a>
# Where is the best location to open a new Jazz Club in Manhattan?  Determine similar neighborhoods to where existing Jazz venues are and find similar ones without a local Jazz Club.

# %% [markdown]
# ## 1.2 Problem <a name="problem"></a>
# The business understanding is to identify which neighborhood(s) are a best match for a location, based on:
# - Finding where existing Jazz Clubs are currently located
# - Discovering what type of neighborhood category they are in
# - Find a similar neighborhood that doesn't currently have a Jazz Venue

# %% [markdown]
# ## 1.3 Audience <a name="audience"></a>
# The target audience for this would be anyone considering moving to Manhattan without detailed knowledge of the area.  This report is a specific study on Jazz Club categories but this approach and the search criteria could easily be amended to repeat the exercise for a different category of venue.

# %% [markdown]
# # 2. Data <a name="data"></a>
#
# To investigate this problem we will need the following datasets of information:
# * List of neighborhoods in Manhattan
# * Location of existing Jazz Clubs and other venues
#
#
# Using the neighborhood data from the dataset previously provided on this course (https://cocl.us/new_york_dataset) we can obtain the geo coordinates of the Manhattan neighborhoods and store the following information:
#
#
#  	Borough 	Neighborhood 	Latitude 	Longitude
# 6 	Manhattan 	Marble Hill 	40.876551 	-73.910660
# 100 	Manhattan 	Chinatown 	40.715618 	-73.994279
# 101 	Manhattan 	Washington Heights 	40.851903 	-73.936900
#
# This data provides:
# 1. Borough name - eg Manhattan
# 2. Neighborhood - eg marble hill, highlights the area within Manhattan
# 3. Latitude - latitude coordinate for mapping
# 4. Longitude - longitude coordinate for mapping

# %% [markdown]
# Additionally, we can retrieve Population information for each neighborhood from the NYC open source: https://opendata.cityofnewyork.us/
#
# This data can can read in using geopandas and then we are able to perform various mapping functions against the dataframe which may help with the investigation.

# %% [markdown]
# The neighborhood data will be compared using the venue data retrieved from foursquare to produce clusters of similar neighborhoods.  The Jazz Club venues will then be placed in those clusters to see whether there is a pattern of cluster for a venue such as a jazz Club to help form a recommendation.

# %% [markdown]
# ### Import the necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

import geopandas as gpd

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
import json    

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library
from folium import Choropleth, Marker
from folium.plugins import HeatMap, MarkerCluster

import math
from area import area


print('Folium installed')
print('Libraries imported.')

def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Foursquare

# %%
CLIENT_ID = 'IZ3OANXNNHAGM2NO1FBTZ4WWGRLJPQORTA1EC4LEY3GTWJGO' # your Foursquare ID
CLIENT_SECRET = 'A3DOWBNWOGPZKSVYP04IY2UE1FSFBQNIDSKGDLRYG5XVQAD1' # your Foursquare Secret
VERSION = '20200604'
LIMIT = 100
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: IZ3OANXNNHAGM2NO1FBTZ4WWGRLJPQORTA1EC4LEY3GTWJGO
# CLIENT_SECRET:A3DOWBNWOGPZKSVYP04IY2UE1FSFBQNIDSKGDLRYG5XVQAD1

# %% [markdown]
# We can explore the foursquare database using the API call with Manhattan coordinates and retrieve all the existing venues in the area, including Jazz clubs

# %%
address = 'Manhattan, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7896239 -73.9598939

# %% [markdown]
# `address = 'Manhattan, NY'
#
# geolocator = Nominatim(user_agent="foursquare_agent")
# location = geolocator.geocode(address)
# latitude = location.latitude
# longitude = location.longitude
# print(latitude, longitude)`

# %%
Search specifically for the existing jazz clubs
# Out:
#   File "<ipython-input-6-6a701545aeaf>", line 1
#     Search specifically for the existing jazz clubs
#                       ^
# SyntaxError: invalid syntax

# %%
search_query = 'Jazz Club'
# removed radius as there aren't any Jazz clubs in centre of Manhattan!
# radius = 500
print(search_query + ' .... OK!')
# Out:
# Jazz Club .... OK!

# %% [markdown]
# define and submit the url to foursquare API...

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    latitude, 
    longitude, 
    VERSION, 
    search_query, 
#     radius, 
    LIMIT
    )

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ee1232a1f420b59219461e6'},
#  'response': {'venues': [{'id': '54ed2952498ec36f92b69d0c',
#     'name': "Dizzy's Jazz Club",
#     'location': {'address': '10 Columbus Cir',
#      'lat': 40.768764,
#      'lng': -73.982944,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.768764,
#        'lng': -73.982944}],
#      'distance': 3027,
#      'postalCode': '10019',
#      'cc': 'US',
#      'neighborhood': "Hell's Kitchen",
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Columbus Cir',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4aca81a1f964a52028c220e3',
#     'name': "Cecil's Jazz Club & Restaurant",
#     'location': {'address': '364 Valley Rd',
#      'lat': 40.77451572910885,
#      'lng': -74.23987875864671,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.77451572910885,
#        'lng': -74.23987875864671},
#       {'label': 'entrance', 'lat': 40.774557, 'lng': -74.239832}],
#      'distance': 23659,
#      'postalCode': '07052',
#      'cc': 'US',
#      'city': 'West Orange',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['364 Valley Rd',
#       'West Orange, NJ 07052',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '52195a0211d247f3c3341b9d',
#     'name': 'Scat Jazz Club',
#     'location': {'lat': 40.81248873725435,
#      'lng': -73.94121455002853,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81248873725435,
#        'lng': -73.94121455002853}],
#      'distance': 2992,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '55a5818d498ef469b908d8e2',
#     'name': "Cassandra's Jazz Club",
#     'location': {'lat': 40.81397710077426,
#      'lng': -73.94463005164623,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81397710077426,
#        'lng': -73.94463005164623}],
#      'distance': 3000,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'shortName': 'Lounge',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4ecca0d7c2ee2da025cee7ac',
#     'name': 'The Wood Jazz Club',
#     'location': {'address': 'Netherwood Cir',
#      'lat': 40.59267589003585,
#      'lng': -74.35265779495239,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.59267589003585,
#        'lng': -74.35265779495239}],
#      'distance': 39745,
#      'postalCode': '08820',
#      'cc': 'US',
#      'city': 'Edison',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Netherwood Cir',
#       'Edison, NJ 08820',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4efd5dbc9a520dfd63fec22a',
#     'name': 'News Room Jazz Club',
#     'location': {'lat': 40.813046343574044,
#      'lng': -73.90864084603515,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.813046343574044,
#        'lng': -73.90864084603515}],
#      'distance': 5044,
#      'postalCode': '10451',
#      'cc': 'US',
#      'city': 'Bronx',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Bronx, NY 10451', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '49dae3daf964a520bd5e1fe3',
#     'name': 'Smalls Jazz Club',
#     'location': {'address': '183 W 10th St',
#      'crossStreet': 'btwn 4th St & 7th Ave S',
#      'lat': 40.734358,
#      'lng': -74.002789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.734358,
#        'lng': -74.002789},
#       {'label': 'entrance', 'lat': 40.734355, 'lng': -74.002759}],
#      'distance': 7136,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['183 W 10th St (btwn 4th St & 7th Ave S)',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '103059498'},
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4ff26425e4b0f0083b1bbb50',
#     'name': 'Jazz Club Hub',
#     'location': {'lat': 40.712785672206365,
#      'lng': -74.00435997750171,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.712785672206365,
#        'lng': -74.00435997750171}],
#      'distance': 9339,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10013', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4eda0c0b722e1da301ca7eea',
#     'name': 'Jazz Club',
#     'location': {'address': '4 SV Ave.',
#      'lat': 40.91131451795595,
#      'lng': -74.0563437647999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.91131451795595,
#        'lng': -74.0563437647999}],
#      'distance': 15794,
#      'postalCode': '07607',
#      'cc': 'US',
#      'city': 'Maywood',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['4 SV Ave.', 'Maywood, NJ 07607', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4fcbc485e4b092ee2363fcee',
#     'name': 'The Jazz Club',
#     'location': {'lat': 40.68416654403854,
#      'lng': -73.95552481176175,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.68416654403854,
#        'lng': -73.95552481176175}],
#      'distance': 11745,
#      'postalCode': '11216',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Brooklyn, NY 11216', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4eccd8d5f7908e99a1a31593',
#     'name': 'Jazz. Club',
#     'location': {'lat': 40.61530735813873,
#      'lng': -73.95474991497144,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.61530735813873,
#        'lng': -73.95474991497144}],
#      'distance': 19409,
#      'postalCode': '11230',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['Brooklyn, NY 11230', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4edbc7160e61d46ad9adbd0c',
#     'name': 'Jazz Club',
#     'location': {'address': '2078 Pearson St, Brooklyn, NY 11234',
#      'lat': 40.61264419555664,
#      'lng': -73.91876220703125,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.61264419555664,
#        'lng': -73.91876220703125}],
#      'distance': 20004,
#      'postalCode': '11234',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2078 Pearson St, Brooklyn, NY 11234',
#       'Brooklyn, NY 11234',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4d4cab9538d9a1437eee2222',
#     'name': 'Bass Line Jazz Club',
#     'location': {'address': '130 E 1st St',
#      'crossStreet': 'Brookdale place',
#      'lat': 40.91178113450523,
#      'lng': -73.83176052866705,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.91178113450523,
#        'lng': -73.83176052866705}],
#      'distance': 17358,
#      'postalCode': '10550',
#      'cc': 'US',
#      'city': 'Mount Vernon',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['130 E 1st St (Brookdale place)',
#       'Mount Vernon, NY 10550',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '54c7403d498e8aaf1a5bf10c',
#     'name': 'Trumpets Jazz Club & Restaurant',
#     'location': {'lat': 40.8171189,
#      'lng': -74.210686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8171189,
#        'lng': -74.210686}],
#      'distance': 21353,
#      'cc': 'US',
#      'city': 'Montclair',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Montclair, NJ', 'United States']},
#     'categories': [],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4c27885b905a0f4772056560',
#     'name': 'Night Light Cafe & Jazz Club',
#     'location': {'address': '1657 Sheepshead Bay Rd',
#      'lat': 40.586431,
#      'lng': -73.951891,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.586431,
#        'lng': -73.951891},
#       {'label': 'entrance', 'lat': 40.586392, 'lng': -73.952091}],
#      'distance': 22629,
#      'postalCode': '11235',
#      'cc': 'US',
#      'city': 'Brooklyn',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1657 Sheepshead Bay Rd',
#       'Brooklyn, NY 11235',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4b8464a1f964a520cd3231e3',
#     'name': 'Trumpets Jazz Club & Restaurant',
#     'location': {'address': '6 Depot Sq',
#      'crossStreet': 'at Walnut St',
#      'lat': 40.81704160889788,
#      'lng': -74.21052702150884,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.81704160889788,
#        'lng': -74.21052702150884},
#       {'label': 'entrance', 'lat': 40.817086, 'lng': -74.21066}],
#      'distance': 21338,
#      'postalCode': '07042',
#      'cc': 'US',
#      'city': 'Montclair',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['6 Depot Sq (at Walnut St)',
#       'Montclair, NJ 07042',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '50458400e4b01cb67a4ccf11',
#     'name': 'The Blue Jazz Club',
#     'location': {'lat': 41.019943,
#      'lng': -73.979863,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.019943,
#        'lng': -73.979863}],
#      'distance': 25693,
#      'postalCode': '07675',
#      'cc': 'US',
#      'city': 'Westwood',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Westwood, NJ 07675', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '504582f5e4b06002d97c4934',
#     'name': 'Blue Jazz Club',
#     'location': {'lat': 41.019919,
#      'lng': -73.979871,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 41.019919,
#        'lng': -73.979871}],
#      'distance': 25691,
#      'postalCode': '07675',
#      'cc': 'US',
#      'city': 'Westwood',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['Westwood, NJ 07675', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d11f941735',
#       'name': 'Nightclub',
#       'pluralName': 'Nightclubs',
#       'shortName': 'Nightclub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/nightclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4e2ba7c318a80bb0585c7a14',
#     'name': 'Larry Young Jazz Club',
#     'location': {'address': '50 Brandford Place',
#      'crossStreet': 'Washington Street',
#      'lat': 40.852496361665736,
#      'lng': -74.30088703041622,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.852496361665736,
#        'lng': -74.30088703041622}],
#      'distance': 29565,
#      'postalCode': '07102',
#      'cc': 'US',
#      'city': 'Newark',
#      'state': 'NJ',
#      'country': 'United States',
#      'formattedAddress': ['50 Brandford Place (Washington Street)',
#       'Newark, NJ 07102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4c47a87496abd13a66be7101',
#     'name': 'Smoke Jazz & Supper Club',
#     'location': {'address': '2751 Broadway',
#      'crossStreet': 'btwn W 105th & W 106th St',
#      'lat': 40.80107489000833,
#      'lng': -73.96786574517584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.80107489000833,
#        'lng': -73.96786574517584},
#       {'label': 'entrance', 'lat': 40.801099, 'lng': -73.968172}],
#      'distance': 1440,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['2751 Broadway (btwn W 105th & W 106th St)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e5931735',
#       'name': 'Music Venue',
#       'pluralName': 'Music Venues',
#       'shortName': 'Music Venue',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '48325453'},
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '3fd66200f964a5205ee81ee3',
#     'name': 'Jazz on the Park Hostel',
#     'location': {'address': '36 W 106th St',
#      'crossStreet': 'Central Park West',
#      'lat': 40.79830920182899,
#      'lng': -73.96099492061344,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79830920182899,
#        'lng': -73.96099492061344}],
#      'distance': 971,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['36 W 106th St (Central Park West)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4d377322dd896a31ac8a2921',
#     'name': 'Jazz on Amsterdam Ave Hostel',
#     'location': {'address': '201 West 87th St, New York',
#      'lat': 40.78854725887858,
#      'lng': -73.9749010026916,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78854725887858,
#        'lng': -73.9749010026916}],
#      'distance': 1270,
#      'postalCode': '10024',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['201 West 87th St, New York',
#       'New York, NY 10024',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4b980f59f964a520ac2935e3',
#     'name': 'Jazz at Lincoln Center',
#     'location': {'address': '10 Columbus Cir',
#      'crossStreet': 'at W 60th St',
#      'lat': 40.76822422081554,
#      'lng': -73.98279190063477,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76822422081554,
#        'lng': -73.98279190063477}],
#      'distance': 3066,
#      'postalCode': '10023',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['10 Columbus Cir (at W 60th St)',
#       'New York, NY 10023',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1e7931735',
#       'name': 'Jazz Club',
#       'pluralName': 'Jazz Clubs',
#       'shortName': 'Jazz Club',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4beec9012c082d7f76da3042',
#     'name': 'Jazz Museum of Harlem',
#     'location': {'address': '104 E 126th St',
#      'crossStreet': 'at Park Ave',
#      'lat': 40.8054469157015,
#      'lng': -73.93834433401543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.8054469157015,
#        'lng': -73.93834433401543}],
#      'distance': 2529,
#      'postalCode': '10035',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 E 126th St (at Park Ave)',
#       'New York, NY 10035',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d181941735',
#       'name': 'Museum',
#       'pluralName': 'Museums',
#       'shortName': 'Museum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4b9d849ff964a52087b136e3',
#     'name': 'Club Normandie',
#     'location': {'address': '225 E 95th St',
#      'crossStreet': 'Btw 2nd & 3rd Ave',
#      'lat': 40.784920890143646,
#      'lng': -73.94853276492782,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.784920890143646,
#        'lng': -73.94853276492782}],
#      'distance': 1091,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['225 E 95th St (Btw 2nd & 3rd Ave)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '509ec40ce4b07eb4d91ab5ee',
#     'name': 'Jazz & Color',
#     'location': {'lat': 40.7983,
#      'lng': -73.958,
#      'labeledLatLngs': [{'label': 'display', 'lat': 40.7983, 'lng': -73.958}],
#      'distance': 978,
#      'postalCode': '10026',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10026', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f2931735',
#       'name': 'Performing Arts Venue',
#       'pluralName': 'Performing Arts Venues',
#       'shortName': 'Performing Arts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4ca1139cd3c2b60c4fa0e2bc',
#     'name': 'Jazz On The Park #2',
#     'location': {'address': '50 W 105th St',
#      'crossStreet': 'Manhattan ave',
#      'lat': 40.797940999999994,
#      'lng': -73.962409,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.797940999999994,
#        'lng': -73.962409},
#       {'label': 'entrance', 'lat': 40.798036, 'lng': -73.962334}],
#      'distance': 949,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['50 W 105th St (Manhattan ave)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '51884ffd498ecde2b8c16810',
#     'name': 'Jazz Gourmet',
#     'location': {'address': '51 W 106th St',
#      'crossStreet': 'Manhattan',
#      'lat': 40.79877071574931,
#      'lng': -73.96115563502221,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.79877071574931,
#        'lng': -73.96115563502221},
#       {'label': 'entrance', 'lat': 40.798862, 'lng': -73.96159}],
#      'distance': 1023,
#      'postalCode': '10025',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['51 W 106th St (Manhattan)',
#       'New York, NY 10025',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d146941735',
#       'name': 'Deli / Bodega',
#       'pluralName': 'Delis / Bodegas',
#       'shortName': 'Deli / Bodega',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4cc11dea56bda0932934ea35',
#     'name': 'Jazz Hostles On Lenox',
#     'location': {'address': '104 W 128th St',
#      'lat': 40.80974062484195,
#      'lng': -73.94481131219545,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.80974062484195,
#        'lng': -73.94481131219545},
#       {'label': 'entrance', 'lat': 40.809834, 'lng': -73.944676}],
#      'distance': 2574,
#      'postalCode': '10027',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 W 128th St',
#       'New York, NY 10027',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1ee931735',
#       'name': 'Hostel',
#       'pluralName': 'Hostels',
#       'shortName': 'Hostel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False},
#    {'id': '4bfdc1ee4cf820a199feecf4',
#     'name': 'One Carnegie Hill Health Club',
#     'location': {'address': '215 E 96th St',
#      'crossStreet': 'btwn 2nd & 3rd Ave',
#      'lat': 40.78508311450944,
#      'lng': -73.94809288449594,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.78508311450944,
#        'lng': -73.94809288449594}],
#      'distance': 1115,
#      'postalCode': '10128',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['215 E 96th St (btwn 2nd & 3rd Ave)',
#       'New York, NY 10128',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1591813037',
#     'hasPerk': False}]}}

# %% [markdown]
# From this we can extract the following useful features:
# 1. venue name
# 2. venue location
# 3. venue address
# 4. distance from search coordinates
# ...

# %% [markdown]
# From the Foursquare lab in the previous module, we know that all the information is in the items key. Before we proceed, let's borrow the get_category_type function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
  
nearby_venues = json_normalize(venues) # flatten JSON


# filter the category for each row
nearby_venues['categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns and keep everything after the full spot
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues['name']
# Out:
# 0                   Dizzy's Jazz Club
# 1      Cecil's Jazz Club & Restaurant
# 2                      Scat Jazz Club
# 3               Cassandra's Jazz Club
# 4                  The Wood Jazz Club
# 5                 News Room Jazz Club
# 6                    Smalls Jazz Club
# 7                       Jazz Club Hub
# 8                           Jazz Club
# 9                       The Jazz Club
# 10                         Jazz. Club
# 11                          Jazz Club
# 12                Bass Line Jazz Club
# 13    Trumpets Jazz Club & Restaurant
# 14       Night Light Cafe & Jazz Club
# 15    Trumpets Jazz Club & Restaurant
# 16                 The Blue Jazz Club
# 17                     Blue Jazz Club
# 18              Larry Young Jazz Club
# 19           Smoke Jazz & Supper Club
# 20            Jazz on the Park Hostel
# 21       Jazz on Amsterdam Ave Hostel
# 22             Jazz at Lincoln Center
# 23              Jazz Museum of Harlem
# 24                     Club Normandie
# 25                       Jazz & Color
# 26                Jazz On The Park #2
# 27                       Jazz Gourmet
# 28              Jazz Hostles On Lenox
# 29      One Carnegie Hill Health Club
# Name: name, dtype: object

# %% [markdown]
# OK, so we've got 30 clubs returned.  There appear to be a few anomolies and the odd mis-categorisation but it doesn't look likes it going to cause a problem for our analysis.  Let's get some population data on Manhattan and a geojson file of the shape of the neighborhoods so we can map them.  We can easily manipulate geo data from various filetypes using geopandas

# %%
# read the neighborhood population data into a DataFrame and load the GeoJSON data
df = pd.read_csv('../nycvisualization/New_York_City_Population_By_Neighborhood_Tabulation_Areas.csv')
# nycmap = json.load(open("nyc_neighborhoods.geojson"))
nycmap = gpd.read_file("../nycvisualization/nyc_neighborhoods.geojson")

# align the column name for NTA code
df.rename(columns={'NTA Code':'ntacode'}, inplace=True)

# %%
# just want the Manhattan boro data
df = df[df['Borough']=='Manhattan']
nycmap = nycmap[nycmap['boro_name']=='Manhattan'].set_index('ntacode')


plot_dict = pd.DataFrame(df.groupby(['ntacode'])['Population'].max())
nycmap.head()
# Out:
#             shape_area county_fips                            ntaname  \
# ntacode
# MN06     10647077.5264         061                     Manhattanville
# MN15     18362149.2813         061                            Clinton
# MN27     14501868.1603         061                          Chinatown
# MN25     19014298.8996         061  Battery Park City-Lower Manhattan
# MN14     15805586.3147         061                     Lincoln Square
#
#             shape_leng  boro_name boro_code  \
# ntacode
# MN06     17040.6854129  Manhattan         1
# MN15     34481.6287742  Manhattan         1
# MN27     20786.2561105  Manhattan         1
# MN25     43738.4962191  Manhattan         1
# MN14     19869.9083199  Manhattan         1
#
#                                                   geometry
# ntacode
# MN06     MULTIPOLYGON (((-73.94608 40.82126, -73.94640 ...
# MN15     MULTIPOLYGON (((-73.99383 40.77293, -73.99379 ...
# MN27     MULTIPOLYGON (((-73.98382 40.72147, -73.98386 ...
# MN25     MULTIPOLYGON (((-74.00078 40.69429, -74.00096 ...
# MN14     MULTIPOLYGON (((-73.97500 40.77753, -73.97546 ...

# %% [markdown]
# Let's map the population density of each neighborhood onto a choropleth, and add on the location of our Jazz Clubs

# %%
# Create a base map
m_1 = folium.Map(location=[latitude, longitude], tiles='cartodbpositron', zoom_start=11)

# Add a choropleth map to the base map
Choropleth(geo_data=nycmap.__geo_interface__, 
           data=plot_dict['Population'], 
           key_on="feature.id", 
           fill_color='YlGnBu', 
           legend_name='Population of each Neighborhood as of 2010',
           hover_name='ntaname'
          ).add_to(m_1)

# Add a marker for each jazz club
for idx, row in nearby_venues[nearby_venues['city']=='New York'].iterrows():
    Marker([row['lat'], row['lng']], popup=row['name']).add_to(m_1)


# Display the map
embed_map(m_1,"choroJazz.html")
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="choroJazz.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %% [markdown]
# Transform the data into a pandas dataframe

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# We're only interested in the Manhattan neighborhoods, so create a manhattan dataframe with just manhattan borough

# %%
manhattan = neighborhoods.loc[neighborhoods['Borough']=='Manhattan']
manhattan.head()
# Out:
#        Borough        Neighborhood   Latitude  Longitude
# 6    Manhattan         Marble Hill  40.876551 -73.910660
# 100  Manhattan           Chinatown  40.715618 -73.994279
# 101  Manhattan  Washington Heights  40.851903 -73.936900
# 102  Manhattan              Inwood  40.867684 -73.921210
# 103  Manhattan    Hamilton Heights  40.823604 -73.949688

# %% [markdown]
# Create a map of New York showing Manhattan neighborhoods and the position of the existing Jazz Clubs superimposed on top of a choropleth map coloured to show the population density of each neighborhood.
#
#     Blue circles = geographic centre of Neighborhoods
#     Marker = Jazz Club location

# %%
# Create a base map
m_1 = folium.Map(location=[latitude, longitude], tiles='cartodbpositron', zoom_start=11)

# Add a choropleth map to the base map
Choropleth(geo_data=nycmap.__geo_interface__, 
           data=plot_dict['Population'], 
           key_on="feature.id", 
           fill_color='YlGnBu', 
           legend_name='Population of each Neighborhood as of 2010',
           hover_name='ntaname'
          ).add_to(m_1)

# add markers to map
for lat, lng, borough, label in zip(manhattan['Latitude'], manhattan['Longitude'], manhattan['Borough'], manhattan['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(m_1)  

# Add a marker for each jazz club
for idx, row in nearby_venues[nearby_venues['city']=='New York'].iterrows():
    Marker([row['lat'], row['lng']], popup=row['name']).add_to(m_1)


# Display the map
embed_map(m_1,"choroClubsClusters.html")
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="choroClubsClusters.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# explore Neighborhoods of Manhattan

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
venues = getNearbyVenues(names=manhattan['Neighborhood'],
                                   latitudes=manhattan['Latitude'],
                                   longitudes=manhattan['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %% [markdown]
# which neighborhoods have the current jazz clubs

# %%
# print(venues.shape)
venues[venues['Venue Category']=='Jazz Club']['Neighborhood']
# Out:
# 378        Central Harlem
# 471       Upper East Side
# 1341    Greenwich Village
# 1503         East Village
# 1883         West Village
# 1897         West Village
# 1912         West Village
# 1940         West Village
# Name: Neighborhood, dtype: object

# %% [markdown]
# We have all the Jazz clubs within Manhattan, which neighborhoods they are in, and we know the population density of each of the neighborhoods.
#
# This concludes the data gathering phase.

# %% [markdown]
# # 3. Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on finding existing Jazz Clubs in the Manhattan borough of New York City, identify the neighborhoods where they reside, and then looking for neighborhoods with similar demographics based on other venue types and population density, but with fewer Jazz Clubs (or none!)
#
# In first step we have collected the required data: **location and type (category) of every Jazz Club within 10km from the centre of Manhattan.** We have also **identified all the venues within Manhattan** currently held in the Foursquare database.
#
# Second step in our analysis will be calculating and explorating **'Jazz Club density'** across different neighborhoods of Manhattan - we will use  **geodata** and **choropleth maps** to identify population density (neighborhood area / population count recorded) in each neighborhood, and comparing which neighborhoods are similar but without Jazz Clubs.
#
# In third and final step we will create clusters (using k-means clustering) of the neighborhoods to identify general zones / neighborhoods / addresses which should be a starting point for final 'street level' exploration and search for optimal venue location by stakeholders.

# %% [markdown]
# Start preparing the data for k-means analysis

# %%
# one hot encoding
manhattan_onehot = pd.get_dummies(venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
manhattan_onehot['Neighborhood'] = venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]

manhattan_onehot.sample(10)
# Out:
#             Neighborhood  Accessories Store  Adult Boutique  \
# 1501        East Village                  0               0
# 1709        Little Italy                  0               0
# 622            Yorkville                  0               0
# 1942        West Village                  0               0
# 867       Lincoln Square                  0               0
# 61             Chinatown                  0               0
# 143   Washington Heights                  0               0
# 2243  Financial District                  0               0
# 2808          Turtle Bay                  0               0
# 2881          Tudor City                  0               0
#
#       Afghan Restaurant  African Restaurant  American Restaurant  \
# 1501                  0                   0                    0
# 1709                  0                   0                    0
# 622                   0                   0                    0
# 1942                  0                   0                    0
# 867                   0                   0                    0
# 61                    0                   0                    0
# 143                   0                   0                    0
# 2243                  0                   0                    0
# 2808                  0                   0                    0
# 2881                  0                   0                    0
#
#       Antique Shop  Arcade  Arepa Restaurant  Argentinian Restaurant  ...  \
# 1501             0       0                 0                       0  ...
# 1709             0       0                 0                       0  ...
# 622              0       0                 0                       0  ...
# 1942             0       0                 0                       0  ...
# 867              0       0                 0                       0  ...
# 61               0       0                 0                       0  ...
# 143              0       0                 0                       0  ...
# 2243             0       0                 0                       0  ...
# 2808             0       0                 0                       0  ...
# 2881             0       0                 0                       0  ...
#
#       Video Store  Vietnamese Restaurant  Volleyball Court  Waterfront  \
# 1501            0                      0                 0           0
# 1709            0                      0                 0           0
# 622             0                      0                 0           0
# 1942            0                      0                 0           0
# 867             0                      0                 0           0
# 61              0                      0                 0           0
# 143             0                      0                 0           0
# 2243            0                      0                 0           0
# 2808            0                      0                 0           0
# 2881            0                      0                 0           0
#
#       Whisky Bar  Wine Bar  Wine Shop  Wings Joint  Women's Store  Yoga Studio
# 1501           0         0          0            0              0            0
# 1709           0         0          0            0              0            0
# 622            0         0          0            0              0            0
# 1942           0         0          0            0              0            0
# 867            0         0          0            0              0            0
# 61             0         0          0            0              0            0
# 143            0         0          0            0              0            0
# 2243           0         0          0            0              0            0
# 2808           0         0          0            0              0            0
# 2881           0         0          0            0              0            0
#
# [10 rows x 332 columns]

# %%
manhattan_onehot.shape
# Out:
# (3121, 332)

# %%
manhattan_grouped = manhattan_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# let's focus on neighborhoods with existing Jazz Clubs.

# %%
jazz_grouped = manhattan_grouped[manhattan_grouped['Jazz Club']>0]
jazz_grouped['Neighborhood']
# Out:
# 2        Central Harlem
# 8          East Village
# 12    Greenwich Village
# 35      Upper East Side
# 38         West Village
# Name: Neighborhood, dtype: object

# %%
num_top_venues = 5

for hood in jazz_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = jazz_grouped[jazz_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Central Harlem----
#                   venue  freq
# 0    African Restaurant  0.07
# 1     French Restaurant  0.04
# 2   American Restaurant  0.04
# 3  Gym / Fitness Center  0.04
# 4                   Bar  0.04
#
#
# ----East Village----
#                 venue  freq
# 0                 Bar  0.05
# 1  Mexican Restaurant  0.05
# 2        Cocktail Bar  0.04
# 3         Coffee Shop  0.04
# 4      Ice Cream Shop  0.03
#
#
# ----Greenwich Village----
#                   venue  freq
# 0    Italian Restaurant  0.10
# 1      Sushi Restaurant  0.05
# 2                  Café  0.05
# 3  Caribbean Restaurant  0.02
# 4          Dessert Shop  0.02
#
#
# ----Upper East Side----
#                   venue  freq
# 0    Italian Restaurant  0.08
# 1           Coffee Shop  0.06
# 2                Bakery  0.04
# 3  Gym / Fitness Center  0.04
# 4           Yoga Studio  0.03
#
#
# ----West Village----
#                  venue  freq
# 0   Italian Restaurant  0.07
# 1             Wine Bar  0.05
# 2  American Restaurant  0.05
# 3         Cocktail Bar  0.04
# 4            Jazz Club  0.04

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# What are the top 10 venues for the neighborhoods

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = manhattan_grouped['Neighborhood']

for ind in np.arange(manhattan_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(manhattan_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#         Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0  Battery Park City                  Park                 Hotel
# 1      Carnegie Hill           Coffee Shop                  Café
# 2     Central Harlem    African Restaurant    Chinese Restaurant
# 3            Chelsea           Coffee Shop           Art Gallery
# 4          Chinatown    Chinese Restaurant                Bakery
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Coffee Shop                   Gym         Memorial Site
# 1           Yoga Studio             Bookstore  Gym / Fitness Center
# 2    Seafood Restaurant                   Bar     French Restaurant
# 3        Ice Cream Shop                  Café                Bakery
# 4          Cocktail Bar       Bubble Tea Shop                   Spa
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Playground          Gourmet Shop            Food Court
# 1                   Gym    Italian Restaurant           Pizza Place
# 2  Gym / Fitness Center   American Restaurant                  Park
# 3   American Restaurant          Cocktail Bar               Theater
# 4                   Bar        Ice Cream Shop           Coffee Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0    Mexican Restaurant          Shopping Mall
# 1             Wine Shop  Vietnamese Restaurant
# 2             Cafeteria                Library
# 3    Italian Restaurant                    Bar
# 4   American Restaurant           Optical Shop

# %% [markdown]
# We have a clear indication which neighborhoods currently have Jazz Clubs and what the most popular venues are within those neighborhoods.
#
# Let us now cluster all the neighborhoods and see which ones k-means clusters together.  This will help decide which other neighborhoods are similar to our identified existing "Jazz" neighborhoods.

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

manhattan_grouped_clustering = manhattan_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(manhattan_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 0, 0, 0, 0, 1, 1, 3, 0, 1], dtype=int32)

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

manhattan_merged = manhattan

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
manhattan_merged = manhattan_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

manhattan_merged.head() # check the last columns!
# Out:
#        Borough        Neighborhood   Latitude  Longitude  Cluster Labels  \
# 6    Manhattan         Marble Hill  40.876551 -73.910660               4
# 100  Manhattan           Chinatown  40.715618 -73.994279               0
# 101  Manhattan  Washington Heights  40.851903 -73.936900               3
# 102  Manhattan              Inwood  40.867684 -73.921210               3
# 103  Manhattan    Hamilton Heights  40.823604 -73.949688               3
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 6          Sandwich Place                   Gym           Coffee Shop
# 100    Chinese Restaurant                Bakery          Cocktail Bar
# 101                  Café                Bakery     Mobile Phone Shop
# 102                Lounge    Mexican Restaurant            Restaurant
# 103           Pizza Place           Coffee Shop         Deli / Bodega
#
#     4th Most Common Venue 5th Most Common Venue      6th Most Common Venue  \
# 6             Yoga Studio              Pharmacy            Supplement Shop
# 100       Bubble Tea Shop                   Spa                        Bar
# 101    Mexican Restaurant            Donut Shop  Latin American Restaurant
# 102                Bakery                  Café         Frozen Yogurt Shop
# 103                  Café    Mexican Restaurant             Sandwich Place
#
#     7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 6              Steakhouse    Seafood Restaurant           Pizza Place
# 100        Ice Cream Shop           Coffee Shop   American Restaurant
# 101           Supermarket      Tapas Restaurant        Sandwich Place
# 102    Spanish Restaurant  Caribbean Restaurant    Chinese Restaurant
# 103      Sushi Restaurant          Cocktail Bar                Bakery
#
#     10th Most Common Venue
# 6            Deli / Bodega
# 100           Optical Shop
# 101                   Bank
# 102                   Park
# 103            Yoga Studio

# %% [markdown]
# which cluster label(s) do the neighborhoods with existing jazz clubs have?

# %%
manhattan_merged[manhattan_merged['Neighborhood'].isin(['Central Harlem','Upper East Side','Greenwich Village','East Village','West Village'])]
# Out:
#        Borough       Neighborhood   Latitude  Longitude  Cluster Labels  \
# 105  Manhattan     Central Harlem  40.815976 -73.943211               0
# 107  Manhattan    Upper East Side  40.775639 -73.960508               0
# 117  Manhattan  Greenwich Village  40.726933 -73.999914               0
# 118  Manhattan       East Village  40.727847 -73.982226               0
# 123  Manhattan       West Village  40.734434 -74.006180               0
#
#     1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 105    African Restaurant    Chinese Restaurant    Seafood Restaurant
# 107    Italian Restaurant           Coffee Shop  Gym / Fitness Center
# 117    Italian Restaurant                  Café      Sushi Restaurant
# 118                   Bar    Mexican Restaurant          Cocktail Bar
# 123    Italian Restaurant              Wine Bar   American Restaurant
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 105                   Bar     French Restaurant  Gym / Fitness Center
# 107                Bakery     French Restaurant                   Spa
# 117                   Bar          Dessert Shop    Seafood Restaurant
# 118           Coffee Shop           Pizza Place             Speakeasy
# 123           Pizza Place                  Park             Jazz Club
#
#     7th Most Common Venue    8th Most Common Venue 9th Most Common Venue  \
# 105   American Restaurant                     Park             Cafeteria
# 107             Juice Bar              Yoga Studio   American Restaurant
# 117  Caribbean Restaurant           Sandwich Place                   Spa
# 118              Wine Bar                Juice Bar        Ice Cream Shop
# 123          Cocktail Bar  New American Restaurant                Bakery
#
#     10th Most Common Venue
# 105                Library
# 107              Wine Shop
# 117     Chinese Restaurant
# 118     Seafood Restaurant
# 123            Coffee Shop

# %% [markdown]
# OK, cluster label 0 is unanimously the cluster for a Jazz Bar.
#
# Finally, let's map the clustered neighborhoods on top of the map showing the population density and existing Jazz Clubs.

# %%
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add cluster markers to the existing map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.5).add_to(m_1)

# Display the map
embed_map(m_1, 'finalClustered.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="finalClustered.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=20,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.5).add_to(map_clusters)
    
for idx, row in nearby_venues[nearby_venues['city']=='New York'].iterrows():
    Marker([row['lat'], row['lng']]).add_to(map_clusters)    
       
# Show the map
embed_map(map_clusters, 'map_clusters.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="map_clusters.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 4. Results <a name="results"></a>

# %% [markdown]
# The analysis shows that there are Jazz Club venues spread all around Manhattan with more centred around Manhattan Valley, near West 106th Street, and 3 near Central Harlem, around West 131-133rd Street.  These are both towards the northern end of Manhattan.
#
# All of the neighborhoods with existing Jazz Clubs were put into the cluster 0.
#
# There are several cluster 0 neighborhoods with similar population density without an existing Jazz Club and these are

# %% [markdown]
# # 5. Discussion <a name="discussion"></a>

# %% [markdown]
# On the surface cluster 0 neighborhoods appear to be good candidates to locate a Jazz Club.  However, there could be other factors as to why they haven't been chosen as venues before.  Perhaps it would be better to locate a specialist club such as a JAzz venue near to other existing clubs where there may be an existing ambiance.

# %% [markdown]
# # 6. Conclusion <a name="conclusion"></a>

# %% [markdown]
# The purpose of this project was to identify a potential Jazz Club location in Manhattan in a neighhorhood where ther wasn't currently a Jazz Club.  Additional information of characteristics of neighborhoods, population density and clustering of similar venue types together were also used to provide a scientific approach to the research.
#
# The final decision on where to location a new Jazz Club would still require additional information and research, taking into account the general atmosphere of a location, closeness to major roads, rental prices, whether tourism numbers has an effect on such a venue, etc.
